# %%
import pandas as pd
import numpy as np

# %%
import seaborn as sns
from matplotlib import pyplot as plt

# %%
drive = pd.read_csv('differential_expression/lim_res_rnai_drive_sublineage_NEW.csv',index_col=0)
rnai = pd.read_csv('differential_expression/lim_res_rnai_achilles_sublineage_NEW.csv',index_col=0)
#crispr = pd.read_csv('Limma/lim_res_crispr.csv',index_col=0)

# %%
# drive.loc[:,['EffectSize','p.value','q.value']].to_csv('tables/supp_table_2_DRIVE-RNAi.csv')
# rnai.loc[:,['EffectSize','p.value','q.value']].to_csv('tables/supp_table_2_Achilles-RNAi.csv')
#crispr.loc[:,['EffectSize','p.value','q.value']].to_csv('tables/supp_table_2_Achilles-CRISPR.csv')

# %%
#cov_drive = pd.read_csv('Limma/lim_res_drive_covar.csv',index_col=0)
#cov_rnai = pd.read_csv('Limma/lim_res_rnai_covar.csv',index_col=0)
#cov_crispr = pd.read_csv('Limma/lim_res_crispr_covar.csv',index_col=0)

# %%
# cov_drive.loc[:,['EffectSize','p.value','q.value']].to_csv('tables/supp_table_2_DRIVE-RNAi(lineage_as_covariate).csv')
# cov_rnai.loc[:,['EffectSize','p.value','q.value']].to_csv('tables/supp_table_2_Achilles-RNAi(lineage_as_covariate).csv')
# cov_crispr.loc[:,['EffectSize','p.value','q.value']].to_csv('tables/supp_table_2_Achilles-CRISPR(lineage_as_covariate).csv')

# %%
from cds import plotting

# %%
drive.loc['MAD2L1 (4085)']
# Out:
# EffectSize     -0.265061
# Avg            -1.307097
# t_stat         -2.416769
# p.value         0.016826
# q.value         0.246617
# log_odds       -3.243461
# min_samples    77.000000
# p.left          0.008413
# p.right         0.991587
# q.left          0.285495
# q.right         1.000000
# Name: MAD2L1 (4085), dtype: float64

# %%
from adjustText import adjust_text
from cds import plotting

fix,ax = plt.subplots()
plt.scatter(rnai.loc[:,'EffectSize'],-np.log10(rnai.loc[:,'p.value']),alpha=.2,color='gray',s=10)
plt.scatter(rnai.loc['BUB1B (701)','EffectSize'],-np.log10(rnai.loc['BUB1B (701)','p.value']),color='red')
plt.scatter(rnai.loc['MAD2L1 (4085)','EffectSize'],-np.log10(rnai.loc['MAD2L1 (4085)','p.value']),color='red')
#plt.scatter(rnai.loc['KIF18A (81930)','EffectSize'],-np.log10(rnai.loc['KIF18A (81930)','p.value']),color='red')


plt.xlim(-.3,.3)
plt.xlabel('effect size')
plt.ylabel('-log10(p-value)')
plt.title('RNAi Achilles (lineage subtype as covariate)')
plotting.simpleaxis(ax)

texts = []
for txt in sorted(['BUB1B (701)','MAD2L1 (4085)']):#,'KIF18A (81930)']):
    texts.append(plt.text(rnai.loc[txt,'EffectSize'], -np.log10(rnai.loc[txt,'p.value']),txt.split(' ')[0],color='black'))
adjust_text(texts)
plt.savefig('review_plots/rnai_achilles_sublineage_revision_NEW.png')

# %%
fix,ax = plt.subplots()
plt.scatter(drive.loc[:,'EffectSize'],-np.log10(drive.loc[:,'p.value']),alpha=.2,color='gray',s=10)
plt.scatter(drive.loc['BUB1B (701)','EffectSize'],-np.log10(drive.loc['BUB1B (701)','p.value']),color='red')
plt.scatter(drive.loc['MAD2L1 (4085)','EffectSize'],-np.log10(drive.loc['MAD2L1 (4085)','p.value']),color='red')
#plt.scatter(drive.loc['KIF18A (81930)','EffectSize'],-np.log10(drive.loc['KIF18A (81930)','p.value']),color='red')


plt.xlim(-.7,.7)
plt.xlabel('effect size')
plt.ylabel('-log10(p-value)')
plt.title('RNAi DRIVE (lineage subtype as covariate)')
plotting.simpleaxis(ax)


texts = []
for txt in sorted(['BUB1B (701)','MAD2L1 (4085)']):#,'KIF18A (81930)']):
    texts.append(plt.text(drive.loc[txt,'EffectSize'], -np.log10(drive.loc[txt,'p.value']),txt.split(' ')[0],color='black'))
adjust_text(texts)
plt.savefig('review_plots/rnai_drive_sublineage_revision_NEW.png')

# %%
# from adjustText import adjust_text


# fix,ax = plt.subplots()
# plt.scatter(crispr.loc[:,'EffectSize'],-np.log10(crispr.loc[:,'p.value']),alpha=.2,color='gray',s=10)
# plt.scatter(crispr.loc['BUB1B (701)','EffectSize'],-np.log10(crispr.loc['BUB1B (701)','p.value']),color='red')
# plt.scatter(crispr.loc['MAD2L1 (4085)','EffectSize'],-np.log10(crispr.loc['MAD2L1 (4085)','p.value']),color='red')
# #plt.scatter(crispr.loc['KIF18A (81930)','EffectSize'],-np.log10(crispr.loc['KIF18A (81930)','p.value']),color='red')


# plt.xlim(-.2,.2)
# plt.xlabel('effect size')
# plt.ylabel('-log10(p-value)')
# plt.title('CRISPR Achilles')
# plotting.simpleaxis(ax)


# texts = []
# for txt in sorted(['BUB1B (701)','MAD2L1 (4085)']):#,'KIF18A (81930)']):
#     texts.append(plt.text(crispr.loc[txt,'EffectSize'], -np.log10(crispr.loc[txt,'p.value']),txt.split(' ')[0],color='black'))
# adjust_text(texts)
# plt.savefig('fig1c_init/crispr_achilles.pdf')

# %%
fix,ax = plt.subplots()
plt.scatter(cov_drive.loc[:,'EffectSize'],-np.log10(cov_drive.loc[:,'p.value']),alpha=.2,color='gray',s=10)
plt.scatter(cov_drive.loc['BUB1B (701)','EffectSize'],-np.log10(cov_drive.loc['BUB1B (701)','p.value']),color='red')
plt.scatter(cov_drive.loc['MAD2L1 (4085)','EffectSize'],-np.log10(cov_drive.loc['MAD2L1 (4085)','p.value']),color='red')
#plt.scatter(cov_drive.loc['KIF18A (81930)','EffectSize'],-np.log10(cov_drive.loc['KIF18A (81930)','p.value']),color='red')


plt.xlim(-.4,.4)
plt.xlabel('effect size')
plt.ylabel('-log10(p-value)')
plt.title('RNAi DRIVe (lineage as covariate)')
plotting.simpleaxis(ax)


texts = []
for txt in sorted(['BUB1B (701)','MAD2L1 (4085)']):#,'KIF18A (81930)']):
    texts.append(plt.text(cov_drive.loc[txt,'EffectSize'], -np.log10(cov_drive.loc[txt,'p.value']),txt.split(' ')[0],color='black'))
adjust_text(texts)
plt.savefig('fig1c_init/rnai_drive_covar.pdf')

# %%
fix,ax = plt.subplots()
plt.scatter(cov_rnai.loc[:,'EffectSize'],-np.log10(cov_rnai.loc[:,'p.value']),alpha=.2,color='gray',s=10)
plt.scatter(cov_rnai.loc['BUB1B (701)','EffectSize'],-np.log10(cov_rnai.loc['BUB1B (701)','p.value']),color='red')
plt.scatter(cov_rnai.loc['MAD2L1 (4085)','EffectSize'],-np.log10(cov_rnai.loc['MAD2L1 (4085)','p.value']),color='red')
#plt.scatter(cov_rnai.loc['KIF18A (81930)','EffectSize'],-np.log10(cov_rnai.loc['KIF18A (81930)','p.value']),color='red')


plt.xlim(-.3,.3)
plt.xlabel('effect size')
plt.ylabel('-log10(p-value)')
plt.title('RNAi Achilles (lineage as covariate)')
plotting.simpleaxis(ax)


texts = []
for txt in sorted(['BUB1B (701)','MAD2L1 (4085)']):#,'KIF18A (81930)']):
    texts.append(plt.text(cov_rnai.loc[txt,'EffectSize'], -np.log10(cov_rnai.loc[txt,'p.value']),txt.split(' ')[0],color='black'))
adjust_text(texts)
plt.savefig('fig1c_init/rnai_achilles_covar.pdf')

# %%
fix,ax = plt.subplots()
plt.scatter(cov_crispr.loc[:,'EffectSize'],-np.log10(cov_crispr.loc[:,'p.value']),alpha=.2,color='gray',s=10)
plt.scatter(cov_crispr.loc['BUB1B (701)','EffectSize'],-np.log10(cov_crispr.loc['BUB1B (701)','p.value']),color='red')
plt.scatter(cov_crispr.loc['MAD2L1 (4085)','EffectSize'],-np.log10(cov_crispr.loc['MAD2L1 (4085)','p.value']),color='red')
#plt.scatter(cov_crispr.loc['KIF18A (81930)','EffectSize'],-np.log10(cov_crispr.loc['KIF18A (81930)','p.value']),color='red')


plt.xlim(-.3,.3)
plt.xlabel('effect size')
plt.ylabel('-log10(p-value)')
plt.title('CRISPR Achilles (lineage as covariate)')
plotting.simpleaxis(ax)


texts = []
for txt in sorted(['BUB1B (701)','MAD2L1 (4085)']):#,'KIF18A (81930)']):
    texts.append(plt.text(cov_crispr.loc[txt,'EffectSize'], -np.log10(cov_crispr.loc[txt,'p.value']),txt.split(' ')[0],color='black'))
adjust_text(texts)
plt.savefig('fig1c_init/crispr_achilles_covar.pdf')

# %%
## Now make D (venn diagram)

# %%
sh = set(rnai.index&drive.index)


rnai_ = rnai.loc[sh][rnai.loc[sh,'EffectSize'] < 0]
drive_ = drive.loc[sh][drive.loc[sh,'EffectSize'] < 0]

# %%
rnai_point_1 = rnai_.loc[sh][rnai_.loc[sh,'q.value'] < .1].index
drive_point_1 = drive_.loc[sh][drive_.loc[sh,'q.value'] < .1].index
#crispr_point_1 = crispr[crispr.loc[:,'q.value'] < .1].index
# Out:
# /Users/mkazachk/miniconda3/lib/python3.6/site-packages/ipykernel_launcher.py:3: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#deprecate-loc-reindex-listlike
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/mkazachk/miniconda3/lib/python3.6/site-packages/pandas/core/indexing.py:961: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#deprecate-loc-reindex-listlike
#   return getattr(section, self.name)[new_key]
# /Users/mkazachk/miniconda3/lib/python3.6/site-packages/ipykernel_launcher.py:4: FutureWarning:
# ...

# %%
rnai_point_oh5 = rnai_.loc[sh][rnai_.loc[sh,'q.value'] < .05].index
drive_point_oh5 = drive_.loc[sh][drive_.loc[sh,'q.value'] < .05].index
#crispr_point_oh5 = crispr[crispr.loc[:,'q.value'] < .05].index
# Out:
# /Users/mkazachk/miniconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#deprecate-loc-reindex-listlike
#   """Entry point for launching an IPython kernel.
# /Users/mkazachk/miniconda3/lib/python3.6/site-packages/pandas/core/indexing.py:961: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#deprecate-loc-reindex-listlike
#   return getattr(section, self.name)[new_key]
# /Users/mkazachk/miniconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: FutureWarning:
# ...

# %%
rnai_point_2 = rnai_.loc[sh][rnai_.loc[sh,'q.value'] < .2].index
drive_point_2 = drive_.loc[sh][drive_.loc[sh,'q.value'] < .2].index
#crispr_point_2 = crispr[crispr.loc[:,'q.value'] < .2].index
# Out:
# /Users/mkazachk/miniconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#deprecate-loc-reindex-listlike
#   """Entry point for launching an IPython kernel.
# /Users/mkazachk/miniconda3/lib/python3.6/site-packages/pandas/core/indexing.py:961: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#deprecate-loc-reindex-listlike
#   return getattr(section, self.name)[new_key]
# /Users/mkazachk/miniconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: FutureWarning:
# ...

# %%
rnai_point_25 = rnai_.loc[sh][rnai_.loc[sh,'q.value'] < .25].index
drive_point_25 = drive_.loc[sh][drive_.loc[sh,'q.value'] < .25].index
#crispr_point_25 = crispr[crispr.loc[:,'q.value'] < .25].index
# Out:
# /Users/mkazachk/miniconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#deprecate-loc-reindex-listlike
#   """Entry point for launching an IPython kernel.
# /Users/mkazachk/miniconda3/lib/python3.6/site-packages/pandas/core/indexing.py:961: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#deprecate-loc-reindex-listlike
#   return getattr(section, self.name)[new_key]
# /Users/mkazachk/miniconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: FutureWarning:
# ...

# %%
# !pwd
# Out:
# /Users/mkazachk/Documents/Uris_paper

# %%
from matplotlib_venn import venn2

drive_and_rnai = set(rnai_point_oh5) & set(drive_point_oh5)
# crispr_and_rnai = set(rnai_point_oh5) & set(crispr_point_oh5)
# crispr_drive = set(crispr_point_oh5) & set(drive_point_oh5)
# alll = set(rnai_point_oh5) & set(drive_point_oh5) & set(crispr_point_oh5)

# Custom text labels: change the label of group A
v=venn2(subsets = (len(rnai_point_oh5), len(drive_point_oh5), len(drive_and_rnai),
                   ), set_labels = ('RNAi Achilles', 'RNAi Drive'))

#plt.title('q-value .05')

overlap = set(rnai.index & drive.index)

drive_sig = set(drive_point_oh5)
drive_not_sig =  overlap - set(drive_point_oh5)


rnai_sig = set(rnai_point_oh5)
rnai_not_sig =  set(overlap) - set(rnai_point_oh5)

oddsratio, pvalue = stats.fisher_exact([[len(drive_sig&rnai_sig), len(drive_sig & rnai_not_sig)],
                                        [len(drive_not_sig & rnai_sig), len(drive_not_sig & rnai_not_sig)]])

print(pvalue)

plt.legend(title='p = '+ str(round(pvalue,3)) + '\nat q-value of .05',frameon=False,loc='upper left')

plt.savefig('fig1d_init/q_.05.pdf')
# Out:
# No handles with labels found to put in legend.
# 0.0003034783084366349

# %%
[[len(drive_sig&rnai_sig), len(drive_sig & rnai_not_sig)],
                                        [len(drive_not_sig & rnai_sig), len(drive_not_sig & rnai_not_sig)]]
# Out:
# [[13, 187], [46, 1784]]

# %%
27 + 678
# Out:
# 705

# %%
drive_and_rnai = set(rnai_point_1) & set(drive_point_1)
# crispr_and_rnai = set(rnai_point_1) & set(crispr_point_1)
# crispr_drive = set(crispr_point_1) & set(drive_point_1)
# alll = set(rnai_point_1) & set(drive_point_1) & set(crispr_point_1)

# Custom text labels: change the label of group A
v=venn2(subsets = (len(rnai_point_1), len(drive_point_1), len(drive_and_rnai)), set_labels = ('RNAi Achilles','RNAi Drive'))

overlap = set(rnai.index & drive.index)

drive_sig = set(drive_point_1)
drive_not_sig =  overlap - set(drive_point_1)


rnai_sig = set(rnai_point_1)
rnai_not_sig =  set(overlap) - set(rnai_point_1)

oddsratio, pvalue = stats.fisher_exact([[len(drive_sig&rnai_sig), len(drive_sig & rnai_not_sig)],
                                        [len(drive_not_sig & rnai_sig), len(drive_not_sig & rnai_not_sig)]])

print(pvalue)

plt.legend(title='p = '+ str(round(pvalue,3)) + '\nat q-value of .1',frameon=False,loc='upper left')






plt.savefig('fig1d_init/q_.1.pdf')
# Out:
# No handles with labels found to put in legend.
# 4.461031934005114e-06

# %%
drive_and_rnai = set(rnai_point_25) & set(drive_point_25)
crispr_and_rnai = set(rnai_point_25) & set(crispr_point_25)
crispr_drive = set(crispr_point_25) & set(drive_point_25)
alll = set(rnai_point_25) & set(drive_point_25) & set(crispr_point_25)

# Custom text labels: change the label of group A
v=venn2(subsets = (len(rnai_point_25), len(drive_point_25), len(drive_and_rnai)),
        set_labels = ('RNAi Achilles', 'RNAi Drive'))



overlap = set(rnai.index & drive.index)

drive_sig = set(drive_point_25)
drive_not_sig =  overlap - set(drive_point_25)


rnai_sig = set(rnai_point_25)
rnai_not_sig =  set(overlap) - set(rnai_point_25)

oddsratio, pvalue = stats.fisher_exact([[len(drive_sig&rnai_sig), len(drive_sig & rnai_not_sig)],
                                        [len(drive_not_sig & rnai_sig), len(drive_not_sig & rnai_not_sig)]])

print(pvalue)

plt.legend(title='p = '+ str(round(pvalue,3)) + '\nat q-value of .25',frameon=False,loc='upper left')







plt.savefig('fig1d_init/q_.25.pdf')
# Out:
# No handles with labels found to put in legend.
# 9.765110941794303e-08

# %%
rnai_point_25_ = rnai_.loc[sh][rnai_.loc[sh].loc[:,'q.value'] < .25]
drive_point_25_ = drive_.loc[sh][drive_.loc[sh].loc[:,'q.value'] < .25]
# Out:
# /Users/mkazachk/miniconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#deprecate-loc-reindex-listlike
#   """Entry point for launching an IPython kernel.
# /Users/mkazachk/miniconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#deprecate-loc-reindex-listlike

# %%
#pos_effect_size = drive_point_25_[drive_point_25_.loc[:,'EffectSize']<0]
top_100 = drive_point_25_.sort_values('EffectSize').iloc[0:100]


drive_and_rnai = set(rnai_point_25_.index) & set(top_100.index)



# Custom text labels: change the label of group A
v=venn2(subsets = (len(rnai_point_25_.index), len(top_100), len(drive_and_rnai)),
        set_labels = ('RNAi Achilles', 'RNAi Drive'))



overlap = set(rnai.index & drive.index)

drive_sig = set(top_100.index)
drive_not_sig =  overlap - set(top_100.index)


rnai_sig = set(rnai_point_25)
rnai_not_sig =  set(overlap) - set(rnai_point_25)

oddsratio, pvalue = stats.fisher_exact([[len(drive_sig&rnai_sig), len(drive_sig & rnai_not_sig)],
                                        [len(drive_not_sig & rnai_sig), len(drive_not_sig & rnai_not_sig)]])

print(pvalue)

plt.legend(title='p = '+ str(round(pvalue,5)) + '\nat q-value of .25',frameon=False,loc='upper left')








#plt.savefig('fig1d_init/q_.25.pdf')
# Out:
# No handles with labels found to put in legend.
# 1.3427401615713501e-10

# %%
[[len(drive_sig&rnai_sig), len(drive_sig & rnai_not_sig)],
                                        [len(drive_not_sig & rnai_sig), len(drive_not_sig & rnai_not_sig)]]
# Out:
# [[36, 64], [332, 1598]]

# %%
pos_effect_size = rnai_point_25_[rnai_point_25_.loc[:,'EffectSize']<0]
top_100 = pos_effect_size.sort_values('EffectSize').iloc[0:100]


rnai_and_drive = set(drive_point_25_[drive_point_25_.loc[:,'EffectSize']<0].index) & set(top_100.index)



# Custom text labels: change the label of group A
v=venn2(subsets = (len(drive_point_25), len(top_100), len(rnai_and_drive)),
        set_labels = ('RNAi Drive', 'RNAi Achilles'))



overlap = set(sh)

rnai_sig = set(top_100.index)
rnai_not_sig =  overlap - set(top_100.index)


drive_sig = set(drive_point_25)
drive_not_sig =  set(overlap) - set(drive_point_25)

oddsratio, pvalue = stats.fisher_exact([[len(rnai_sig&drive_sig), len(rnai_sig & drive_not_sig)],
                                        [len(drive_sig & rnai_not_sig), len(drive_not_sig & rnai_not_sig)]])

print(pvalue)

plt.legend(title='p = '+ str(round(pvalue,3)) + '\nat q-value of .25',frameon=False,loc='upper left')








#plt.savefig('fig1d_init/q_.25.pdf')
# Out:
# No handles with labels found to put in legend.
# 4.785021493633312e-10

# %%
[[len(rnai_sig&drive_sig), len(rnai_sig & drive_not_sig)],
                                        [len(drive_not_sig & rnai_sig), len(drive_not_sig & rnai_not_sig)]]
# Out:
# [[39, 61], [61, 6038]]

# %%
len(drive_point_25)
# Out:
# 626

# %%
[[len(drive_sig&rnai_sig), len(drive_sig & rnai_not_sig)],
        [len(drive_not_sig & rnai_sig), len(drive_not_sig & rnai_not_sig)]]
# Out:
# [[349, 1882], [629, 4237]]

# %%
len(overlap)
# Out:
# 7097

# %%
349 + 1882 + 629 + 4237
# Out:
# 7097

# %%
drive_and_rnai = set(rnai_point_25) & set(drive_point_25)
crispr_and_rnai = set(rnai_point_25) & set(crispr_point_25)
crispr_drive = set(crispr_point_25) & set(drive_point_25)
alll = set(rnai_point_25) & set(drive_point_25) & set(crispr_point_25)

# Custom text labels: change the label of group A
v=venn3(subsets = (len(rnai_point_25), len(drive_point_25), len(drive_and_rnai),
                   len(crispr_point_25),len(crispr_and_rnai),
                   len(crispr_drive),len(alll)), set_labels = ('RNAi Achilles', 'RNAi Drive', 'CRISPR Achilles'))

plt.title('q-value .25')

plt.savefig('fig1d_init/q_.25.png')

# %%
import scipy.stats as stats
oddsratio, pvalue = stats.fisher_exact([[len(rnai_point_1), len(drive_point_1)], [len(rnai) - len(rnai_point_1), len(drive) - len(drive_point_1)]])

# %%
pvalue
# Out:
# 4.023191409814119e-236

# %%
len(rnai)
# Out:
# 16755

# %%
len(drive)
# Out:
# 7975

# %%
overlap = rnai.index & drive.index

# %%
drive_sig = set(drive_point_1 & overlap)
drive_not_sig =  set(overlap) - set(drive_point_1)


rnai_sig = set(rnai_point_1 & overlap)
rnai_not_sig =  set(overlap) - set(rnai_point_1)

oddsratio, pvalue = stats.fisher_exact([[len(drive_sig&rnai_sig), len(drive_sig & rnai_not_sig)],
                                        [len(drive_not_sig & rnai_sig), len(drive_not_sig & rnai_not_sig)]])

# %%
pvalue
# Out:
# 2.865917700865685e-06

# %%
[[len(drive_sig&rnai_sig), len(drive_sig & rnai_not_sig)],
                                        [len(drive_not_sig & rnai_sig), len(drive_not_sig & rnai_not_sig)]]
# Out:
# [[85, 1096], [231, 5685]]

# %%
print('p-value of overlap between RNAi achilles and drive: ' + str(pvalue))
# Out:
# p-value of overlap between RNAi achilles and drive: 2.865917700865685e-06

# %%
from scipy import stats
import scipy

# %%
sh = drive.index & rnai.index

fix,ax = plt.subplots()
plt.scatter(drive.loc[sh,'EffectSize'], rnai.loc[sh,'EffectSize'],alpha=.2,s=10,label=None)

plt.scatter(drive.loc['BUB1B (701)','EffectSize'], rnai.loc['BUB1B (701)','EffectSize'],alpha=.5,s=50,label=None,color='red')
plt.scatter(drive.loc['MAD2L1 (4085)','EffectSize'], rnai.loc['MAD2L1 (4085)','EffectSize'],alpha=.5,s=50,label=None,color='red')


r,p = scipy.stats.pearsonr(drive.loc[sh,'EffectSize'],rnai.loc[sh,'EffectSize'])


sns.kdeplot(drive.loc[sh,'EffectSize'], rnai.loc[sh,'EffectSize'])

print(drive.loc[sh,'EffectSize'].corr(rnai.loc[sh,'EffectSize']))
print(r)
print(p)

plt.xlabel('RNAi Drive effect size')
plt.ylabel('RNAi Achilles effect size')

plotting.simpleaxis(ax)


ax.legend(title='r = ' + str(round(r,3)) + '\np = '+ str(round(p,80)),frameon=False)


texts = []
for txt in sorted(['BUB1B (701)','MAD2L1 (4085)']):#,'KIF18A (81930)']):
    texts.append(plt.text(drive.loc[txt,'EffectSize'], rnai.loc[txt,'EffectSize'],txt.split(' ')[0],color='black'))
adjust_text(texts)



plt.savefig('fig1d_init/drive_achilles_rnai.pdf')
# Out:
# /Users/mkazachk/miniconda3/lib/python3.6/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# No handles with labels found to put in legend.
# 0.21959304247801276
# 0.2195930424780126
# 3.0927251316939117e-78

# %%
sh = drive.index & crispr.index

# plt.scatter(drive.loc[sh,'EffectSize'], crispr.loc[sh,'EffectSize'],alpha=.4)
# print(drive.loc[sh,'EffectSize'].corr(crispr.loc[sh,'EffectSize']))


fix,ax = plt.subplots()
plt.scatter(drive.loc[sh,'EffectSize'], crispr.loc[sh,'EffectSize'],alpha=.2,s=10,label=None)



r,p = scipy.stats.pearsonr(drive.loc[sh,'EffectSize'],crispr.loc[sh,'EffectSize'])

plt.scatter(drive.loc['BUB1B (701)','EffectSize'], crispr.loc['BUB1B (701)','EffectSize'],alpha=.5,s=50,label=None,color='red')
plt.scatter(drive.loc['MAD2L1 (4085)','EffectSize'], crispr.loc['MAD2L1 (4085)','EffectSize'],alpha=.5,s=50,label=None,color='red')
sns.kdeplot(drive.loc[sh,'EffectSize'], crispr.loc[sh,'EffectSize'])


print(drive.loc[sh,'EffectSize'].corr(crispr.loc[sh,'EffectSize']))
print(r)
print(p)

plt.xlabel('RNAi Drive effect size')
plt.ylabel('CRISPR Achilles effect size')

plotting.simpleaxis(ax)


ax.legend(title='r = ' + str(round(r,3)) + '\np = '+ str(round(p,45)),frameon=False)
texts = []
for txt in sorted(['BUB1B (701)','MAD2L1 (4085)']):#,'KIF18A (81930)']):
    texts.append(plt.text(drive.loc[txt,'EffectSize'], crispr.loc[txt,'EffectSize'],txt.split(' ')[0],color='black'))
adjust_text(texts)

plt.savefig('fig1d_init/drive_achilles_CRISPR.pdf')
# Out:
# /Users/mkazachk/miniconda3/lib/python3.6/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# No handles with labels found to put in legend.
# 0.1569471122275335
# 0.15694711222753352
# 1.5401814400187954e-41

# %%
sh = rnai.index & crispr.index

# plt.scatter(rnai.loc[sh,'EffectSize'], crispr.loc[sh,'EffectSize'],alpha=.4)
# print(rnai.loc[sh,'EffectSize'].corr(crispr.loc[sh,'EffectSize']))



fix,ax = plt.subplots()
plt.scatter(rnai.loc[sh,'EffectSize'], crispr.loc[sh,'EffectSize'],alpha=.2,s=10,label=None)



r,p = scipy.stats.pearsonr(rnai.loc[sh,'EffectSize'],crispr.loc[sh,'EffectSize'])

plt.scatter(rnai.loc['BUB1B (701)','EffectSize'], crispr.loc['BUB1B (701)','EffectSize'],alpha=.5,s=50,label=None,color='red')
plt.scatter(rnai.loc['MAD2L1 (4085)','EffectSize'], crispr.loc['MAD2L1 (4085)','EffectSize'],alpha=.5,s=50,label=None,color='red')
sns.kdeplot(rnai.loc[sh,'EffectSize'], crispr.loc[sh,'EffectSize'])

texts = []
for txt in sorted(['BUB1B (701)','MAD2L1 (4085)']):#,'KIF18A (81930)']):
    texts.append(plt.text(rnai.loc[txt,'EffectSize'], crispr.loc[txt,'EffectSize'],txt.split(' ')[0],color='black'))
adjust_text(texts)


print(rnai.loc[sh,'EffectSize'].corr(crispr.loc[sh,'EffectSize']))
print(r)
print(p)

plt.xlabel('RNAi Achilles effect size')
plt.ylabel('CRISPR Achilles effect size')

plotting.simpleaxis(ax)


ax.legend(title='r = ' + str(round(r,3)) + '\np = '+ str(round(p,57)),frameon=False)
plt.savefig('fig1d_init/rnai_achilles_CRISPR_achilles.pdf')
# Out:
# /Users/mkazachk/miniconda3/lib/python3.6/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# No handles with labels found to put in legend.
# 0.12556411128722453
# 0.12556411128722444
# 2.1632528599410488e-55

# %%
stats.zscore(rnai.loc[sh,'EffectSize'])
# Out:
# array([ 4.24917805,  6.54928207, -0.44800114, ...,  0.38710023,
#        -0.32827389,  1.343296  ])

# %%
rnai_doubling = pd.read_csv('Limma/lim_res_rnai_achilles_doublings.csv',index_col=0)
drive_doubling = pd.read_csv('Limma/lim_res_rnai_drive_doublings.csv',index_col=0)

# %%
fix,ax = plt.subplots()
plt.scatter(rnai_doubling.loc[:,'EffectSize'],-np.log10(rnai_doubling.loc[:,'p.value']),alpha=.2,color='gray',s=10)
plt.scatter(rnai_doubling.loc['BUB1B (701)','EffectSize'],-np.log10(rnai_doubling.loc['BUB1B (701)','p.value']),color='red')
plt.scatter(rnai_doubling.loc['MAD2L1 (4085)','EffectSize'],-np.log10(rnai_doubling.loc['MAD2L1 (4085)','p.value']),color='red')
#plt.scatter(rnai_doubling.loc['KIF18A (81930)','EffectSize'],-np.log10(rnai_doubling.loc['KIF18A (81930)','p.value']),color='red')


plt.xlim(-.3,.3)
plt.xlabel('effect size')
plt.ylabel('-log10(p-value)')
plt.title('RNAi achilles (genome doublings as covariate)')
plotting.simpleaxis(ax)

texts = []
for txt in sorted(['BUB1B (701)','MAD2L1 (4085)']):#,'KIF18A (81930)']):
    texts.append(plt.text(rnai_doubling.loc[txt,'EffectSize'], -np.log10(rnai_doubling.loc[txt,'p.value']),txt.split(' ')[0],color='black'))
adjust_text(texts)
plt.savefig('fig2f/rnai_doubling_achilles.pdf')

# %%
fix,ax = plt.subplots()
plt.scatter(drive_doubling.loc[:,'EffectSize'],-np.log10(drive_doubling.loc[:,'p.value']),alpha=.2,color='gray',s=10)
plt.scatter(drive_doubling.loc['BUB1B (701)','EffectSize'],-np.log10(drive_doubling.loc['BUB1B (701)','p.value']),color='red')
plt.scatter(drive_doubling.loc['MAD2L1 (4085)','EffectSize'],-np.log10(drive_doubling.loc['MAD2L1 (4085)','p.value']),color='red')
#plt.scatter(drive_doubling.loc['KIF18A (81930)','EffectSize'],-np.log10(drive_doubling.loc['KIF18A (81930)','p.value']),color='red')


#plt.xlim(-.3,.3)
plt.xlabel('effect size')
plt.ylabel('-log10(p-value)')
plt.title('RNAi Drive (genome doublings as covariate)')
plotting.simpleaxis(ax)

texts = []
for txt in sorted(['BUB1B (701)','MAD2L1 (4085)']):#,'KIF18A (81930)']):
    texts.append(plt.text(drive_doubling.loc[txt,'EffectSize'], -np.log10(drive_doubling.loc[txt,'p.value']),txt.split(' ')[0],color='black'))
adjust_text(texts)
plt.savefig('fig2f/rnai_doubling_drive.pdf')
